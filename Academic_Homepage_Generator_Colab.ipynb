# %% [markdown]
# # 🎓 學術主頁生成器 - Google Colab 版
#
# **AI 驅動的學術主頁生成工具**
# 支持 Gemini 2.5 Pro 和 GPT-4o Vision
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/xhh678876/personal_page/blob/main/Academic_Homepage_Generator_Colab.ipynb)
#
# ---
#
# ## ✨ 特點
#
# - 🆓 **完全免費** - 使用 Google Colab 的免費資源
# - 🚀 **無需安裝** - 不需要本地環境
# - 🌐 **雲端運行** - 直接在瀏覽器使用
# - 🤖 **AI 解析** - Gemini/GPT-4o 自動提取簡歷信息
# - 🎨 **炫酷界面** - 與本地版本完全相同的視覺效果
#
# ---
#
# ## 📝 使用步驟
#
# 1. **點擊菜單**：Runtime → Run all（運行所有單元）
# 2. **等待安裝**：約 2-3 分鐘
# 3. **點擊鏈接**：訪問生成的公網地址
# 4. **上傳簡歷**：選擇 PDF 文件
# 5. **獲取網站**：AI 自動生成精美主頁！
#
# ---
#
# ## ⚠️ 重要提示
#
# - Colab 會話有時間限制（90分鐘空閒後斷開）
# - 如果斷開，重新運行所有單元即可
# - 推薦使用 Gemini API（免費額度更多）

# %% [markdown]
# ## 步驟 1: 安裝 Node.js 和 npm
#
# Colab 默認沒有 Node.js，我們需要先安裝它。

# %%
# %%bash
# # 安裝 Node.js 20.x LTS
# echo "📦 正在安裝 Node.js..."
# curl -fsSL https://deb.nodesource.com/setup_20.x | sudo -E bash -
# sudo apt-get install -y nodejs
#
# echo ""
# echo "✅ Node.js 安裝完成！"
# node -v
# npm -v
# Out:
# 📦 正在安裝 Node.js...
# 2025-12-14 08:44:12 - Installing pre-requisites
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,849 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,961 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,537 kB]
# ...

# %% [markdown]
# ## 步驟 2: 從 GitHub 克隆專案
#
# 自動下載最新版本代碼

# %%
# %%bash
# # 清理舊文件（如果存在）
# rm -rf /content/project
#
# # 從 GitHub 克隆項目
# echo "📦 正在從 GitHub 下載專案..."
# git clone https://github.com/xhh678876/personal_page.git /content/project
#
# echo ""
# echo "✅ 專案下載完成！"
# echo "📂 專案位置：/content/project"
# ls -la /content/project | head -20
# Out:
# 📦 正在從 GitHub 下載專案...
#
# ✅ 專案下載完成！
# 📂 專案位置：/content/project
# total 152
# drwxr-xr-x 10 root root  4096 Dec 14 08:44 .
# drwxr-xr-x  1 root root  4096 Dec 14 08:44 ..
# -rw-r--r--  1 root root 13074 Dec 14 08:44 Academic_Homepage_Generator_Colab.ipynb
# drwxr-xr-x  3 root root  4096 Dec 14 08:44 app
# -rw-r--r--  1 root root  5601 Dec 14 08:44 Colab使用指南.md
# drwxr-xr-x  3 root root  4096 Dec 14 08:44 components
# drwxr-xr-x  2 root root  4096 Dec 14 08:44 electron
# -rw-r--r--  1 root root    58 Dec 14 08:44 .eslintrc.js
# drwxr-xr-x  8 root root  4096 Dec 14 08:44 .git
# drwxr-xr-x  3 root root  4096 Dec 14 08:44 .github
# -rw-r--r--  1 root root  4486 Dec 14 08:44 GitHub上傳指南.md
# -rw-r--r--  1 root root   347 Dec 14 08:44 .gitignore
# drwxr-xr-x  2 root root  4096 Dec 14 08:44 hooks
# drwxr-xr-x  2 root root  4096 Dec 14 08:44 lib
# -rw-r--r--  1 root root  2019 Dec 14 08:44 Linux使用指南.md
# -rw-r--r--  1 root root  2308 Dec 14 08:44 package.json
# ...

# %% [markdown]
# ## 步驟 3: 安裝專案依賴
#
# 安裝所有 npm 包（這可能需要 2-3 分鐘）

# %%
# %%bash
# cd /content/project
#
# echo "📦 正在安裝專案依賴..."
# echo "這可能需要 2-3 分鐘，請耐心等待..."
# echo ""
#
# # 使用國內鏡像加速（可選）
# # npm config set registry https://registry.npmmirror.com
#
# npm install
#
# echo ""
# echo "✅ 依賴安裝完成！"
# Out:
# 📦 正在安裝專案依賴...
# 這可能需要 2-3 分鐘，請耐心等待...
#
#
# added 757 packages, and audited 758 packages in 1m
#
# 193 packages are looking for funding
#   run `npm fund` for details
#
# 13 vulnerabilities (8 moderate, 5 high)
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
#
# ✅ 依賴安裝完成！
# npm warn deprecated are-we-there-yet@2.0.0: This package is no longer supported.
# npm warn deprecated npmlog@5.0.1: This package is no longer supported.
# npm warn deprecated gauge@3.0.2: This package is no longer supported.
# npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# npm warn deprecated boolean@3.2.0: Package no longer supported. Contact Support at https://www.npmjs.com/support for more info.
# npm warn deprecated @humanwhocodes/object-schema@2.0.3: Use @eslint/object-schema instead
# npm warn deprecated @humanwhocodes/config-array@0.13.0: Use @eslint/config-array instead
# ...

# %% [markdown]
# ## 步驟 4: 構建 Next.js 應用

# %%
# %%bash
# cd /content/project
#
# echo "🔨 正在構建 Next.js 應用..."
# npm run build
#
# echo ""
# echo "✅ 構建完成！"
# Out:
# 🔨 正在構建 Next.js 應用...
#
# > academic-homepage-generator@1.0.0 build
# > next build
#
# Attention: Next.js now collects completely anonymous telemetry regarding usage.
# This information is used to shape Next.js' roadmap and prioritize features.
# You can learn more, including how to opt-out if you'd not like to participate in this anonymous program, by visiting the following URL:
# https://nextjs.org/telemetry
#
#   ▲ Next.js 14.2.35
#
#    Creating an optimized production build ...
#
# ✅ 構建完成！
# Failed to compile.
#
# ./app/globals.css.webpack[javascript/auto]!=!./node_modules/next/dist/build/webpack/loaders/css-loader/src/index.js??ruleSet[1].rules[14].oneOf[12].use[2]!./node_modules/next/dist/build/webpack/loaders/postcss-loader/src/index.js??ruleSet[1].rules[14].oneOf[12].use[3]!./app/globals.css
# Error: Cannot find module '@tailwindcss/typography'
# Require stack:
# - /content/project/tailwind.config.ts
#     at Module._resolveFilename (node:internal/modules/cjs/loader:1207:15)
# ...

# %% [markdown]
# ## 步驟 5: 啟動應用並創建公網鏈接
#
# 使用 pyngrok 將本地端口暴露到公網

# %%
# 安装 cloudflared（二进制）
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb
# Out:
# Selecting previously unselected package cloudflared.
# (Reading database ... 122895 files and directories currently installed.)
# Preparing to unpack cloudflared-linux-amd64.deb ...
# Unpacking cloudflared (2025.11.1) ...
# Setting up cloudflared (2025.11.1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !!cd /content/project && HOST=0.0.0.0 PORT=3000 npm run dev

# %%
# !cloudflared tunnel --url http://localhost:3000

# %%
import os
import subprocess
import time
import re

# 切换到项目目录
os.chdir('/content/project')

print("🚀 啟動 Next.js...")
next_process = subprocess.Popen(
    ["npm", "run", "dev", "--", "-H", "0.0.0.0", "-p", "3000"],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE,
    text=True
)

# 等待 Next.js 启动
time.sleep(10)

print("🌐 啟動 Cloudflare Tunnel...")
cf_process = subprocess.Popen(
    ["cloudflared", "tunnel", "--url", "http://localhost:3000"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True
)

public_url = None

# 从输出中抓取公网 URL
for line in cf_process.stdout:
    print(line.strip())
    match = re.search(r"https://.*trycloudflare.com", line)
    if match:
        public_url = match.group(0)
        break

print("")
print("=" * 60)
print("🎉 應用已成功暴露到公網！")
print("=" * 60)
print("")
print(f"🌐 訪問鏈接: {public_url}")
print("")
print("⚠️ 提示：Colab 断开后链接会失效")
print("=" * 60)
# Out:
# 🚀 啟動 Next.js...
# 🌐 啟動 Cloudflare Tunnel...
# 2025-12-14T09:03:20Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2025-12-14T09:03:20Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2025-12-14T09:03:23Z INF +--------------------------------------------------------------------------------------------+
# 2025-12-14T09:03:23Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# ...

# %% [markdown]
# ## 🎯 使用 Gemini API（推薦）
#
# ### 獲取免費 API Key
#
# 1. 訪問：https://aistudio.google.com/app/apikey
# 2. 登錄 Google 賬號
# 3. 點擊「Create API Key」
# 4. 複製密鑰（格式：`AIzaSy...`）
# 5. 在應用中粘貼使用
#
# ### 優勢
#
# - ✅ 完全免費
# - ✅ 每分鐘 15 次請求
# - ✅ 響應速度快（10-20秒）
# - ✅ 準確性高

# %% [markdown]
# ## 🛑 停止服務器
#
# 運行下面的單元來停止服務器

# %%
# 停止服務器和 ngrok tunnel
try:
    process.terminate()
    ngrok.kill()
    print("✅ 服務器已停止")
except:
    print("服務器未運行")

# %% [markdown]
# ---
#
# ## 📚 常見問題
#
# ### Q: 鏈接打不開？
# A: 確保所有代碼單元都已運行，並且沒有報錯。等待 10-15 秒讓服務器完全啟動。
#
# ### Q: 會話斷開了？
# A: Colab 會話有時間限制，重新運行所有單元（Runtime → Run all）即可。
#
# ### Q: 想要永久鏈接？
# A: 可以部署到 Vercel/Netlify，或者使用 ngrok 付費版。詳見項目 README。
#
# ### Q: 界面效果和本地一樣嗎？
# A: 完全一樣！所有的漸變、動畫、交互效果都 100% 保留。
#
# ### Q: 可以保存生成的網站嗎？
# A: 可以！在生成後的頁面右鍵保存，或者使用瀏覽器的「另存為」功能。
#
# ---
#
# ## 🚀 本地部署
#
# 如果你想在本地運行（需要 Node.js）：
#
# ```bash
# # 克隆倉庫
# git clone https://github.com/xhh678876/personal_page.git
# cd personal_page
#
# # 安裝依賴
# npm install
#
# # 構建並運行
# npm run build
# npm start
#
# # 訪問 http://localhost:3000
# ```
#
# ## 🌟 生產部署
#
# ### Vercel（推薦 - 免費）
#
# 1. Fork 這個倉庫
# 2. 訪問 https://vercel.com
# 3. Import Git Repository
# 4. 選擇你的 fork
# 5. 點擊 Deploy
# 6. 完成！獲得永久域名
#
# ---
#
# **GitHub 倉庫**: https://github.com/xhh678876/personal_page
# **Made with ❤️ for Researchers**
# *Powered by Gemini 2.0 / GPT-4o Vision*
